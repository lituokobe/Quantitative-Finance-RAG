# %%
import numpy as np
import pandas as pd

# %%
df_naive = pd.read_csv("eval_results_naive_rag.csv")
df_adaptive = pd.read_csv("eval_results_adaptive_rag.csv")

# %%
df_naive
# Out:
#    Unnamed: 0                                         user_input  \
# 0           0  How is WACC calculated if the cost of equity i...
# 1           1   How do stocks and bonds differ as asset classes?
# 2           2                 How do futures and options differ?
#
#                                   retrieved_contexts  \
# 0  ['Calculating WACC: Formula Breakdown\n\nWACC ...
# 1  ["What Are Asset Classes? More Than Just Stock...
# 2  ["Exploring the Types of Options: Calls and Pu...
#
#                                             response  \
# 0  The weighted average cost of capital (WACC) is...
# 1  Stocks and bonds differ as asset classes in th...
# 2  Futures and options differ primarily in the ob...
#
#                                            reference  context_precision  \
# 0  $WACC = w_e * r_e + w_d * r_d * (1-T)$. With $...                1.0
# 1  Stocks represent equity ownership in a company...                1.0
# ...

# %%
df_naive.loc[0, "response"]
# Out:
# 'The weighted average cost of capital (WACC) is calculated by multiplying the cost of each capital source by its respective weight and summing the results. Using the given values—cost of equity of 10%, cost of debt of 5%, equity weight of 60%, and debt weight of 40%—the WACC formula is:\n\nWACC = (Equity weight × Cost of equity) + (Debt weight × Cost of debt × (1 − Tax rate))\n\nHowever, the corporate tax rate (Tc) is not provided in the question. Since the after-tax cost of debt depends on this tax rate, and it is a required component of the WACC calculation, the exact WACC cannot be determined without it.\n\nTherefore, based on the available information, the WACC cannot be fully calculated.'

# %%
df_adaptive.loc[0, "retrieved_contexts"]
# Out:
# '["Calculating WACC: Formula Breakdown\\n\\nWACC is found by determining the proportions of debt and equity financing that a company uses to determine the total cost of capital. The equation is:\\n\\n$$\\\\text{WACC} = \\\\left ( \\\\frac{ E }{ V} * Re \\\\right ) + \\\\left ( \\\\frac{ D }{ V} * Rd * ( 1 - Tc ) \\\\right )$$ \\nwhere:\\n- $\\\\text{Market value of the firm\'s equity}$ \\n- $D = \\\\text{Market value of the firm\'s debt}$\\n- $V = E + D$ \\n- $Re = \\\\text{Cost of equity}$\\n- $Rd = \\\\text{Cost of debt}$\\n- $Tc = \\\\text{Corporate tax rate}$\\n\\nWACC is calculated by multiplying the cost of each capital source (debt and equity) by its relevant weight and then adding those results together. In the formula, E/V shows the proportion of equity financing, and D/V represents the proportion of debt financing. The WACC formula thus involves the summation of two terms:\\n\\n$$\\\\left( \\\\frac{ E }{ V} * Re \\\\right)$$\\n\\n$$\\\\left( \\\\frac{ D }{ V} * Rd * ( 1 - T
# ...

# %%
df_adaptive.loc[0, ""]
